# %% [markdown]
# # Project done as part of the Data Analysis in Python course by Dataquest.

# %% [markdown]
# THIS PROJECT IS FOR PRACTICE THE SKILLS LEARNED AT THE MODULE "IMPROVING PLOT ASTHETICS WITH MATPLOTLIB"

# %% [markdown]
# The original data on jobs outcomes was released by American Community Survey, with the job outcomes of students who graduated from college between 2010 and 2012.
# FiveThirtyEight cleaned the dataset and released it on their GitHub.

# %% [markdown]
# Some questions for this dataset:
#
# Do students in more popular majors make more money?
# - Using scatter plots
#
# How many majors are predominantly male? Predominantly female?
# - Using histograms
#
# Which category of majors have the most students?
# - Using bar plots

# %%
import pandas as pd

# %%
import matplotlib as plt

# %%
# %matplotlib inline

# %%
recent_grads = pd.read_csv('recent-grads.csv')

# %% [markdown]
# # First let's have a general look at the dataset, using .head(), .tail() and .describe()

# %%
print(recent_grads.iloc[0])
print(recent_grads.head())
print(recent_grads.tail())
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
recent_grads.head()
# Out:
#      Rank  Major_code                                          Major  \
# 0       1        2419                          PETROLEUM ENGINEERING
# 1       2        2416                 MINING AND MINERAL ENGINEERING
# 2       3        2415                      METALLURGICAL ENGINEERING
# 3       4        2417      NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4       5        2405                           CHEMICAL ENGINEERING
# 5       6        2418                            NUCLEAR ENGINEERING
# 7       8        5001                     ASTRONOMY AND ASTROPHYSICS
# 6       7        6202                              ACTUARIAL SCIENCE
# 12     13        2404                         BIOMEDICAL ENGINEERING
# 13     14        5008                              MATERIALS SCIENCE
# 10     11        2407                           COMPUTER ENGINEERING
# 9      10        2408                         ELECTRICAL ENGINEERING
# 11     12        2401                          AEROSPACE ENGINEERING
# ...

# %%
recent_grads.describe()

# %% [markdown]
# To remove rows with missing values as it can cause trouble when using matplotlib:

# %%
recent_grads = recent_grads.dropna()
recent_grads.describe()

# %% [markdown]
# # Generating plots using the jupyter magic

# %%
recent_grads.plot(x='Sample_size', y='Median', kind='scatter', title='Sample Size vs Median')

# %%
recent_grads.plot(x='Sample_size', y='Unemployment_rate', kind='scatter', title='Sample Size vs Unemployment')

# %%
recent_grads.plot(x='Full_time', y='Median', kind='scatter', title='Full time vs Median')

# %%
recent_grads.plot(x='ShareWomen', y='Unemployment_rate', kind='scatter', title='Share Women vs Unemployment Rate')

# %%
recent_grads.plot(x='Men', y='Median', kind='scatter', title='Men vs Median')

# %%
recent_grads.plot(x='ShareWomen', y='Median', kind='scatter', title='Women vs Median')

# %% [markdown]
# Let's try to answer some questions based on the above plots:
#
# - Do students in more popular majors make more money?<br>
#     Not necessarily.
# - Do students that majored in subjects that were majority female make more money?<br>
#     I didn't use the plot, but the line of code bellow, which shows the major with the highest proportion of women are not ranking high. I've also changed the plot for better visualisation.<br>
# - Is there any link between the number of full-time employees and median salary?<br>
#     Full time workers apparently earn more.

# %%
recent_grads.sort_values(['ShareWomen','Median'], ascending=False).head()
# Out:
#      Rank  Major_code                                          Major  \
# 164   165        2307                      EARLY CHILDHOOD EDUCATION
# 163   164        6102  COMMUNICATION DISORDERS SCIENCES AND SERVICES
# 51     52        6104                     MEDICAL ASSISTING SERVICES
# 138   139        2304                           ELEMENTARY EDUCATION
# 150   151        2901                   FAMILY AND CONSUMER SCIENCES
#
#         Total      Men     Women                       Major_category  \
# 164   37589.0   1167.0   36422.0                            Education
# 163   38279.0   1225.0   37054.0                               Health
# 51    11123.0    803.0   10320.0                               Health
# 138  170862.0  13029.0  157833.0                            Education
# 150   58001.0   5166.0   52835.0  Industrial Arts & Consumer Services
#
#      ShareWomen  Sample_size  Employed      ...        Part_time  \
# ...

# %%
recent_grads.Sample_size.hist(bins=60, range=(0,3000))

# %%
recent_grads.Median.hist(bins=40, range=(20000,80000))

# %%
recent_grads.Employed.hist(bins=40, range=(0,200000))

# %%
recent_grads.Full_time.hist(bins=30)

# %%
recent_grads.ShareWomen.hist(bins=40)

# %%
recent_grads.Unemployment_rate.hist(bins=25)

# %%
recent_grads.Men.hist(bins=30, range=(0,100000))

# %%
recent_grads.Women.hist(bins=30, range=(0,100000))

# %% [markdown]
# - What percent of majors are predominantly male? Predominantly female?<br>
#     It is almost balanced, with a slightly predominance of men.
# - What's the most common median salary range?<br>
#     Around 36k dollars per year.

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(recent_grads[['Sample_size','Median']], figsize=(6,6))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1174149b0>,
# ...
#       dtype=object)

# %%
scatter_matrix(recent_grads[['Sample_size','Median','Unemployment_rate']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x116870c18>,
# ...
#       dtype=object)

# %%
scatter_matrix(recent_grads[['ShareWomen','Median']], figsize=(8,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x117edd6a0>,
# ...
#       dtype=object)

# %%
recent_grads[:10].plot.bar(x='Major',y='ShareWomen', legend=False)
recent_grads[163:].plot.bar(x='Major',y='ShareWomen', legend=False)

# %%
recent_grads[:10].plot.bar(x='Median',y='Men', legend=False)
recent_grads[163:].plot.bar(x='Median',y='Men', legend=False)
